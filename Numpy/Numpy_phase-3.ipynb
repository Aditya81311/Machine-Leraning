# %% [markdown]
# ## Advance Operations With Business Examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

# %%
print("==== Zomato sales analysis ==== ")
print("Shape Of Data:: ",sales_data.shape)
print("First 3 Restarunt Data::\n", sales_data[:3])
# Out:
# ==== Zomato sales analysis ====
# Shape Of Data::  (5, 5)
# First 3 Restarunt Data::
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
#Total Sales per Year
yearly_total = np.sum(sales_data[:,1:],axis = 0)
print("Total Sales Per Year:: ",yearly_total)

min_sales = np.min(sales_data[:,1:],axis=1)
print(" Minimum Sales Per Reataurant:: ",min_sales)

# Maximum Sales Per Reataurant
max_sales = np.max(sales_data[:,1:],axis=0)
print(" Maximum Sales Per Reataurant:: ",max_sales)

# Avrage Sales Per Restaurant
avg_sales = np.mean(sales_data[:,1:],axis=1)
print(" Average Sales Per Reataurant:: ",avg_sales)

# Cumalative Sales
cumulative_sales = np.cumsum(sales_data[:, 1:],axis=1)
print("Cumalative Sales:: ", cumulative_sales)
# Out:
# Total Sales Per Year::  [ 810000  945000 1085000 1240000]
#  Minimum Sales Per Reataurant::  [150000 120000 200000 180000 160000]
#  Maximum Sales Per Reataurant::  [200000 230000 260000 300000]
#  Average Sales Per Reataurant::  [200000. 152500. 247500. 225000. 195000.]
# Cumalative Sales::  [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
# Plot Cumulative Sales

plt.figure(figsize=(8,6))
plt.plot(np.mean(cumulative_sales,axis=0))
plt.title("Avrage Cumulative Sales Per Year")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Vector Operations

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("Vector Addition:: ",vector1 + vector2)
print("Vector Multiplaction:: ", vector1 * vector2)
print("Vector Dot Product:: ", np.dot(vector1 , vector2))
angle =  np.arccos(np.dot(vector1 , vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print("Vector Angle:: ",angle)
# Out:
# Vector Addition::  [ 7  9 11 13 15]
# Vector Multiplaction::  [ 6 14 24 36 50]
# Vector Dot Product::  130
# Vector Angle::  0.26554161733900966

# %%
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper:: ", vectorized_upper(restaurant_types))
# Out:
# Vectorized Upper::  ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:,1:] / 12
print("Monthly Avrage:: ", monthly_avg)
# Out:
# Monthly Avrage::  [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
